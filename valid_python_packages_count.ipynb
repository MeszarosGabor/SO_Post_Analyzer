# %%
import collections
import json

# %%
from utils.valid_python_packages import get_all_package_names

# %%
package_names = { item.lower() for item in get_all_package_names()}

# %%
len(package_names)
# Out:
# 570421

# %%
with open("data/results/python/python_libs_first_dates.json") as handle:
    all_libs = json.load(handle)

# %%
len(all_libs)
# Out:
# 66498

# %%
all_lib_names = {item.lower() for item in all_libs.keys()}

# %%
len(package_names & all_lib_names) / len(all_lib_names)
# Out:
# 0.35187878594147076

# %%
all_lib_names - package_names
# Out:
# {'item2',
#  'lab_utils_uni',
#  'stuff_data',
#  'lcterminalpdb',
#  'world_elements',
#  'mksfunction',
#  'transaction_analytics',
#  'namespace1',
#  'service_rest',
#  'memberstable',
#  'highlevelcrypto',
#  'faktable',
#  'selectable_edit',
#  'bp_includes',
#  'fivetran_pulumi',
#  'post_tweet',
#  'check_empty',
#  'mycharts',
#  'communityattendanceapp',
#  'grpc_server',
#  'jmmlib',
#  'engine45',
#  'createproperty',
#  '+',
#  'bcncat',
#  'gt_ent',
#  'get_ext',
#  'signatureapp',
#  'samples',
#  'a_info',
#  'test_list',
#  'ez_scrip_lib',
#  "'posixpath'",
#  'capitaliser_bnd',
#  '<b>django_apscheduler',
#  'pywofost',
#  '")',
#  'videoclasses',
#  'viewboxcustom',
#  "'users",
#  'manchinetranslator',
#  'stopserver_wlst',
#  'regex_file_cleaner',
#  'objects/methodobject',
#  'realtime_bidding_pb2',
#  'bootstrap/dist/css/bootstrap',
#  'outputvcard',
#  'urlopener',
#  'jacksparrow',
#  'pisa_default',
#  'viewcontroller',
#  'dagama',
#  'test_details_by_name',
#  'ui_minigui',
#  'random_selection',
#  'decidingturn',
#  'booking_spider',
#  'testdbase',
#  'bar_pack',
#  'admin_component',
#  'some_other_mod',
#  'wolframpythonalpha',
#  'stackoverflow2',
#  'characterslist',
#  'queryapplicationstatusrequest',
#  'result_import',
#  'simulationtimer',
#  'home_page_strings',
#  'singlepost',
#  'mymoduleforthisuglysolution',
#  'helper_db',
#  'fastcontacts',
#  'errorrep',
#  'threadpooltestwithdb_io',
#  'parametrage',
#  'flask_app2',
#  'matplotlib_util',
#  'testitemwidget',
#  'mydatabasescript',
#  'installed_io',
#  'ethanol_model',
#  'madnotez',
#  'generate_series(1',
#  'mis',
#  'module_helloworld',
#  'module_you_wanted',
#  'slave_script',
#  'noths',
#  'sub_command_baz',
#  'listaproduccion',
#  'keylite',
#  'wafer_diagram',
#  'pyslow',
#  'sample_tree1',
#  'read_from_file_or_net',
#  'banking_functions',
#  'facedetector_m',
#  'mygrammarparser',
#  'another_package',
#  'module_abc',
#  'file_to_execute',
#  'simplebutton',
#  'rftextfield',
#  'isfloat',
#  'mp_utils</code>',
#  'applaboratorio',
#  'great_library',
#  'eventoccurrence',
#  'downloadfunction',
#  'module_paths',
#  'sniffer_wideband_v09',
#  'cheetax',
#  'file_processor',
#  'celery1',
#  'solutionsforlanguagesapp',
#  'preprocessingfunction',
#  'my_matlab_app',
#  'internetspeedtwitterbot',
#  '((segments',
#  'testionq',
#  'mysubplot',
#  'typecontrol',
#  'globalcheck',
#  'psqlextra',
#  'httpresponseredirect',
#  'ebike_msgs',
#  'page_maker',
#  'pgcompleter',
#  'mustdo',
#  'simpleinference',
#  'libcore',
#  'keymap',
#  'externallibrary',
#  'eventbased',
#  '/usr/lib/x86_64-linux-gnu/libboost_python-py34',
#  'errors1',
#  'getcameras',
#  'a_table',
#  'matcompat',
#  'tesseract-ocr',
#  'wilma',
#  'example_cython',
#  '_ida_hexrays',
#  'project_lib',
#  'persen',
#  'db_scripts',
#  'myresource_rc',
#  'discrd',
#  'program-name',
#  'sa_auth_keys',
#  'yourmainpyfilename',
#  'sikuliwrapper',
#  'loadbatches',
#  'file&gt',
#  'boot_django',
#  'walascan',
#  'gitscripts',
#  'db_model',
#  'jeras',
#  'dxpyfeed',
#  'settings_template',
#  'teamshandler',
#  'blogapp',
#  '_sphtools',
#  'parent_dir',
#  'oldimport',
#  'audit_log',
#  'gremlin_python',
#  'splash_ui',
#  'nektime',
#  'jena',
#  'generate_class_module',
#  'outbreakmap',
#  'blynktimer',
#  'max31865',
#  'h2oaicore',
#  'polytemplate',
#  'mpbfunctions',
#  'ne_pki_service',
#  'ctxmgr',
#  'bigscrape',
#  'authinduction',
#  'completed',
#  'update_model',
#  'askmate',
#  'professors',
#  'storyline',
#  'pulseio',
#  'escraperinterfaceapp',
#  'tkb',
#  'test_debugger',
#  'pysqlite2',
#  'projectfoo',
#  'dbruntime',
#  'dataseta',
#  'studentsearch',
#  'search_app',
#  'customviewer',
#  'telnetconnectionextended',
#  'skued',
#  'second_class',
#  'renderprocess',
#  '_ckernel',
#  'dot_csv',
#  'my_wrapper',
#  '/tmp/pip-install-bpmeop26/h5py/h5py/api_compat',
#  'passageiro',
#  'ccs_renewal_message',
#  'sparksession',
#  'gapro',
#  'dash_application',
#  'some_main_module',
#  'asynctimer',
#  'testimbd',
#  'cpkg_resources',
#  'agrc',
#  'autobowgui',
#  'my_cool_app',
#  'trapzdv',
#  'tikadotnet',
#  'countries_app',
#  'imagehandler',
#  'soapguild',
#  'sendrecv',
#  'text_processing_plugin',
#  'myapp_support',
#  'mnist_dataset',
#  'convertsvg',
#  'drda',
#  '_gst',
#  'beach',
#  'static_data_app',
#  'loadandsave',
#  'verifications',
#  'opening_questions',
#  'sparse_slice',
#  'multi_sensor_acc_gyro1',
#  'build_cfg',
#  'c:\\users\\pichi\\downloads\\boost_1_79_0/boost/function/function_base',
#  'heart_beat',
#  'functions_definition',
#  'imaginary_sequence_counter&quot',
#  'datasetprocess',
#  'bindata2',
#  'ipywidget',
#  'indices',
#  'excel_adapter',
#  'dotgame',
#  'pkg_2',
#  'point_class',
#  'sogou_mrc',
#  'module_smalltools',
#  'abidwise_detail',
#  '_mymodulea',
#  'download_ibama',
#  'wiiremote',
#  'membersrouter',
#  'gebruikers',
#  'gen9db',
#  'money_model',
#  'mock_autogen',
#  'doc1',
#  'chemwindow',
#  'timerlcdnumber',
#  'dbpost_processing',
#  'pyramidapp',
#  'actualization',
#  'import_test_set',
#  'tools/boost-for-sds2-2016/include/boost/python/class',
#  'dbscriptdeploy',
#  'chatbotx1',
#  'timesseriesgraph',
#  'dosaamismodtotal',
#  'lockerrentalform',
#  'ocm',
#  'componenta',
#  'simplematrixgui',
#  'al4',
#  'bybitwebsocket',
#  'aluno',
#  'import2sql_life',
#  'nnet_comb_mod',
#  'my-library',
#  'runnermod',
#  'baxter_core_msgs',
#  'getports',
#  'serialinterface',
#  'imoveis',
#  'eye_tracker_copy',
#  'pandas&quot',
#  'csvmanipulation',
#  'recipe_scraper',
#  'job_scraper',
#  'applist',
#  'csv<br>from',
#  'employees_pb2',
#  'xratedkkusd_test',
#  'service_handlers',
#  'instance_stack',
#  'some_functions',
#  'bot_file',
#  'incoming_volume',
#  'tm2_val_lab',
#  'myinit',
#  'ourdb',
#  'mathmodule',
#  '/lib/x86_64-linux-gnu/libglib-2',
#  'router_move',
#  'pyobjctools',
#  'bs2',
#  'udpclient',
#  'audio_read',
#  'sqlrelay',
#  'time</code>',
#  'colour_profile',
#  'strategy4',
#  'celery_worker',
#  'testinguser',
#  'eiris_wipro',
#  'timecycle',
#  'getmediaid',
#  'startstoprestart',
#  'unicode_strings',
#  '***',
#  'signals_generator',
#  'transfer_function',
#  'url_datasets',
#  'temperaturereader',
#  'otherscript',
#  "'package:protobuf/protobuf",
#  'contactus_noncustomer',
#  'netoworkx',
#  'site1',
#  "'dart:html'",
#  'mainappframe',
#  'plugins/python/wsgi_subhandler',
#  '[whatever',
#  'djan_frontend',
#  'server_keys',
#  'word',
#  'vggs',
#  '"protobufs/common',
#  'top_module',
#  'connectdialog',
#  'mrp_bom',
#  'lambdafunction',
#  'c:\\users\\pichi\\downloads\\boost_1_79_0/boost/python/detail/copy_ctor_mutates_rhs',
#  'appsname',
#  'backupui',
#  'rtsp_threaded_tracker',
#  'imageuploader',
#  'singletonobject',
#  'rtag',
#  'top_rows',
#  'facebi',
#  'split_data',
#  'coin_acceptor',
#  'epm',
#  'a_finder',
#  'pyxmltest',
#  'genericfile',
#  'ecomproject',
#  'const_for_drdo_adaptive_split',
#  'myconst',
#  'newscengen',
#  'occt',
#  'obj_b',
#  'testcases_v4',
#  'mcubes',
#  'someclasses',
#  'nb_diplomes_dept',
#  'test_gradient_for_python_layer',
#  'stack_class',
#  'burtapi',
#  'meleeweapons',
#  'webdat',
#  '/usr/local/include/boost/function/function_base',
#  'windowhandler',
#  'kaffee',
#  'evergreen_common',
#  'bakerydemo',
#  'avg2',
#  'mcve_framework',
#  'xyxyxyxyxyxy',
#  'libdispatch',
#  'expression_lib',
#  'dataiku',
#  '3rdpartylib',
#  'custom_class_1',
#  'dc_globals',
#  'importtracking',
#  'my_flask_project',
#  'test_by_me',
#  'mobile_module',
#  'xba',
#  'qlineedit_test',
#  'testtype2',
#  'terminalsize',
#  'gpstracking',
#  "'json'",
#  'stocks_db',
#  'newyorkscraper',
#  'weather_fetch',
#  '{some_table}',
#  'addedfile',
#  'stortitimer',
#  'scprag',
#  'pyplum',
#  'place&gt',
#  'way_too_slow',
#  'pscrapper',
#  'pg_description',
#  'some_time_library',
#  'pytorch_net',
#  'lib7',
#  'import_corpus_mod',
#  'get_events_devices',
#  'buisnesscard',
#  'inputdata',
#  'supportedlang',
#  'sampleapp_entry_authors',
#  'custom_operation',
#  'quries',
#  'markdown_it',
#  'follower',
#  '/tmp/pip-install-88jz6z10/dlib_645016c7ef8843149dbaaf156d8387b7/dlib/external/pybind11/include/pybind11/detail/common',
#  'test_mp',
#  'process_url',
#  'device1',
#  'schools',
#  'our_a',
#  'datetiem',
#  'shopes',
#  'getwebjson',
#  '28)',
#  'gfk',
#  'sqlfile',
#  'trading_ig_config',
#  'backed',
#  'image_iter',
#  'seebid',
#  'login_form_base',
#  'pick1',
#  'requests_proxychain',
#  'scritp2',
#  'edqm',
#  'ask_islam',
#  'script_search',
#  'dos_website',
#  'clientsecrets',
#  '[script1]',
#  'pydevd_vm_type',
#  'blzip',
#  '_kernel',
#  'prankheader',
#  'stats_fantasy',
#  'simulador',
#  'flying_dragon',
#  'schedule_email',
#  'playlistcreator',
#  'contact_requests',
#  'jobs_struct',
#  'submodels/model4',
#  'xbmc',
#  'scrap_site',
#  'cudpred',
#  'escola',
#  'sparkmethods',
#  'outsourced',
#  'keyboardbutton',
#  '=j["from"]',
#  'pyconwinpy',
#  'oauthtwitter',
#  'slotset',
#  'invest_web',
#  'smtplib`enter',
#  'dirname1',
#  'studentapp',
#  '`tabsales',
#  'pandas/src/datetime/np_datetime',
#  'ownutilities',
#  'placeorder',
#  'special_library',
#  'gspylib',
#  'afterlogin',
#  'test_webapp',
#  'multiscorer',
#  'scriptcommander',
#  'aesify',
#  'd:\\anaconda\\envs\\neural\\lib\\site-packages\\~cipy-1',
#  'pseudopython-org',
#  'sims4',
#  'backend_wx',
#  'movtomxf',
#  'cartrejecteddiscounts',
#  'table""")',
#  'voice_to_text',
#  'socbindtry',
#  'unitrunner',
#  'hook_utils',
#  'alsaaudio',
#  'onlyonremoteserver',
#  'config_s',
#  'createevent',
#  'this:</p>',
#  'sjbcd',
#  'the_module_with_dictionaries',
#  'pytestloop',
#  'my_awesome_imaginary_utils',
#  'ui_myform',
#  'ebm_icealbfeedback',
#  'menuscreen',
#  'schede_tecniche',
#  'snow_get',
#  'northafricatutorial',
#  'recognition',
#  'thinair',
#  'newhomaa',
#  'matplolib',
#  'myobj',
#  'holds',
#  'missile',
#  'test_folder_2',
#  '/usr/include/pybind11/pybind11',
#  'trymypy',
#  'spatial_encoder',
#  'process4',
#  'data_handling',
#  'table3',
#  '{debug}',
#  'hgrm_messages',
#  'file_dialog',
#  'my_parsers',
#  'djangofun',
#  'adobe',
#  'oslo_service',
#  'update_df',
#  '##dedupemail',
#  'libdesklets',
#  'mpl3115a2',
#  'cmemcache',
#  'avtogumi',
#  'clyng',
#  '/usr/include/boost/get_pointer',
#  'dev_user',
#  'old_form_ambulance_usage_report',
#  'job_posting_layer',
#  'predict_script',
#  'tbi',
#  'showapp',
#  'origdata',
#  'simplemathcaptcha',
#  'evening',
#  'linkedlistnode',
#  'extensions/osr_wrap',
#  'cosnaming',
#  '_wx',
#  'xorf',
#  'turtle</p>',
#  'database("sqlite:///var/database',
#  'custom_python_file',
#  '/usr/lib/libpython3',
#  'feature_function',
#  'cosnotifychanneladmin',
#  'authorizer',
#  'smsincoming',
#  'consumer',
#  'idbconnection',
#  'progressbar12',
#  'my_other_module_that_i_dont_want_to_reload',
#  'remove_duplicate',
#  'libimaging/bands',
#  'habit_add_remove_page',
#  'subclass',
#  'apis_for_trading',
#  'eventmethods',
#  'flickeringboxes',
#  'settings_general',
#  'this',
#  'main_sample',
#  'globalex1',
#  'h5handler',
#  'blackcrowtours',
#  '</p>',
#  'write_gen_code',
#  'acm',
#  'download_clips',
#  'diya_info',
#  'functions_library',
#  'tech_support',
#  'jon',
#  'ayam_ui',
#  'myclass',
#  '"google/protobuf/any',
#  'protofile_pb2_grpc',
#  'e25',
#  'sys</code><br',
#  'ocempgui',
#  'test_launch',
#  'c:',
#  'spection',
#  'psymatik',
#  'celery_c',
#  'generic_relations',
#  'receipt',
#  'd:',
#  'dopinfo',
#  'col1',
#  'zorba_api',
#  'natmailer',
#  'core_app',
#  'pp_json',
#  'igdb',
#  'simple_multi_unet_model',
#  'printing_functions_1',
#  'problematic',
#  'site2',
#  'cnn_model_fn',
#  'ekichabidemo',
#  'libfortran1',
#  'latexlexer',
#  'c4rules',
#  '"python"',
#  'file_b',
#  'debugutil',
#  'characters_data',
#  'formbutton',
#  'transpaper_dataholder',
#  'image_pb2',
#  'win32ras',
#  'dynamicthread',
#  'auth_handler',
#  'rank2_log',
#  'creditcards',
#  'zinnia_extra',
#  'td[3]',
#  'extract_metadata',
#  'batchiterator',
#  'rpi_order_data_sync',
#  'formprocessing',
#  'scrapeinfo',
#  'browser_autopilot',
#  'coco_metric',
#  'kiseats3app',
#  'keyrsa',
#  'dynamo_utils',
#  'adafruit_lsm303_accel',
#  'importantfunction',
#  'dummylibrary',
#  'suproccess',
#  'fakeutils',
#  'companybase',
#  'fighters',
#  'test_http_client',
#  'ip_file_valid',
#  'gimpenums',
#  'scipy/spatial/ckdtree/src/ckdtree_globals',
#  '`843777',
#  'manuals_project',
#  'get_sth_test',
#  'aboutdatasets',
#  'getkeys',
#  'extractplot3ddata',
#  'msgrid',
#  'webiopi',
#  'nitrogencorrector',
#  '//needed',
#  'stackwidgettest',
#  'pconv',
#  '(irb):36&gt',
#  'pages_1',
#  'wordpresslib',
#  'forspef_scrapper',
#  'production_settings',
#  'pan_read',
#  'my_strategy',
#  'twitter_credentials',
#  'appfolder',
#  'body_parser',
#  'hn_gui',
#  'ui_ded',
#  'filter_design',
#  'scratch_1',
#  'other_function',
#  'min_content',
#  'appinfopage',
#  'rest_framework_docs',
#  'jumbodjango',
#  'garage_parking',
#  'arrayqueue',
#  'newyork',
#  'botpass',
#  'module_in_parent_dir',
#  'db_wrap',
#  'htmlprocessing',
#  'appsfolder',
#  'mcbot',
#  'py3lib-2',
#  'csvfilegen1',
#  'dualsite',
#  'api_view',
#  'requestsurl',
#  'nextdialog',
#  'splunk_wan_methods',
#  'players_teams',
#  'yourproto_pb2',
#  'project',
#  'mon_agent',
#  'readschema',
#  'plotcanvas',
#  'ml_algorithms_learning',
#  'hackmanager',
#  'ws_route',
#  'loginapi',
#  'pais',
#  'lo_conn_3',
#  'a_standard',
#  'piicodev_unified',
#  'cumulativesender',
#  'eval_print',
#  'riskfolio',
#  'aprobio',
#  'test_file2',
#  'filesys_ops',
#  'cythonic',
#  'pickling_module',
#  'add_nic_to_vm',
#  'model_base',
#  'coinpayments',
#  'mymodelfile',
#  'ui_sss',
#  'myliba',
#  'mpl_defaults',
#  'graph2d',
#  'recepciondoc',
#  'dassoc_app',
#  'ytdl_variables',
#  '*imports',
#  'postprocessing',
#  'pgblog',
#  'maptlotlib',
#  'sim1',
#  'token_file',
#  'generate_json',
#  'multiprocclass',
#  'your_other_module',
#  'swiftsocket',
#  'cmask',
#  'prueba_browser',
#  'makeinfo',
#  'ssd1306_stamp',
#  'onehelper',
#  'pmo_review_task',
#  'view_name',
#  'test_interface',
#  'chatsend',
#  'routetools',
#  'mym',
#  'powerful',
#  'maker37cb',
#  'myfoofile',
#  'ui_subframe2',
#  'parallelioctl',
#  'main_tab',
#  'google_play_billing',
#  'transpositionencrypt',
#  'otproject',
#  'func_randomgame',
#  'pagescroller',
#  'dttools',
#  'monocypher',
#  'resourcehandler',
#  'webdiligent',
#  'e_cidadania',
#  'dialog_code',
#  'tp_api',
#  'map_reducer',
#  'my_new_app',
#  'blpinterface',
#  'zfunctions',
#  "'_struct'",
#  'hfnetcdf',
#  'other_api',
#  'fut_sig',
#  'jobtype2',
#  '3rd_praty_lib',
#  'location_form',
#  'urllib`',
#  '/tmp/pip-install-2tn4k8le/vowpalwabbit/vowpalwabbit/ect',
#  'audiofield',
#  'djangocrud',
#  'amount',
#  'cpp14parserbase',
#  'asnycio',
#  'project_pkg',
#  'plotservice',
#  'backtests',
#  'udpserver',
#  'agroom2',
#  'os<br>',
#  'calender',
#  'tomvar',
#  'faceobject',
#  'scrambld_back',
#  'tone_player',
#  'createroom',
#  'sop_management',
#  'updated',
#  'pycococreatortools',
#  'typing_question_screen',
#  'mcif',
#  'oldtable',
#  'orders_service',
#  'botmain',
#  'mocked_external_module',
#  'wiki_plugins_tags',
#  'new_empty_file',
#  'scoringtools',
#  'dictsalmostequal',
#  'jinjacms',
#  'settitle',
#  'tileclass',
#  'mock_tutorial',
#  'fcr_cv',
#  'envdefault',
#  's3boto',
#  'cecoresizer',
#  'botteleneck',
#  'extern_module',
#  'image_file_name',
#  'matrixes',
#  'myclass_63948475',
#  'parser_tests',
#  'skincare',
#  'mutiprocesscomunicate',
#  'does_not_exist',
#  'fortran:',
#  'youtube_statistics',
#  'minimal_pygame',
#  '/home/udowyxdf/virtualenv/downloader/3',
#  'bootstrapyieldcurve',
#  'synthtool',
#  'historias',
#  'parsemywork',
#  'final_functions',
#  'cts_not_polite',
#  'vtkmodules',
#  'api_code',
#  'cte_',
#  'juniperj2320',
#  'utils_general',
#  '_jsonnet',
#  'google_worksheets',
#  'plotterresources',
#  'somemodel',
#  'idctor',
#  'opetator',
#  'markov_model',
#  'testwebapp',
#  'initgui',
#  'flogui',
#  'doraemonsay',
#  'postgres_copy',
#  'hire',
#  '/private/var/folders/t4/cb7x5vw1057cblh52hpnf0v00000gp/t/pip-uninstall-xx1tqvgd/__pycache__/_ipaddress',
#  'pocketsphinx_inmic',
#  'gpustruct',
#  'assigning',
#  'promotions',
#  'pressao',
#  'parking_ticket',
#  'tabwidget_ui',
#  'lib_xml',
#  'package_name&gt',
#  'url2dictionary',
#  'py_cpp_bind',
#  'make_vid',
#  '__webimport__',
#  'traceit',
#  'fishery',
#  'parameter_file_input',
#  'in_dir1',
#  '/tmp/pip-install-nx1hok9_/dlib/dlib/external/pybind11/include/pybind11/detail/common',
#  'f5sdk',
#  'tasks_producer',
#  'wfdbtools',
#  'airapp',
#  '/tmp/pip-install-unk5_9mx/dlib/dlib/external/pybind11/include/pybind11/cast',
#  'pdfnetc',
#  'getoldtweets',
#  'websockethread',
#  'secret_stuff',
#  'common_file',
#  'callback_manager',
#  'fedora_college',
#  'summalogic',
#  'data_plot',
#  'pidmon',
#  '/usr/lib/gcc/i686-pc-cygwin/3',
#  'openpxyl',
#  'functions_email',
#  'your-app',
#  'second_pb2_grpc',
#  'algoscore',
#  'flabstraction',
#  'preañapro',
#  'timedcontext',
#  'myrestaurants',
#  'somewhere_else',
#  'choosestyle',
#  'sess',
#  'module_key_letter',
#  'filetotest',
#  'my_virtual_module',
#  'spam_pb2_grpc',
#  'log_path_str',
#  'spider1',
#  'reactdom',
#  'nextcloud_client',
#  'b_backend',
#  'cpamie',
#  'documentscanner',
#  'con_pos',
#  'load_fw',
#  'c:\\users\\rohit\\appdata\\local\\programs\\python\\python37-32\\lib\\site-packages\\~ysqldb',
#  'mobile_status',
#  'pyjmi',
#  'cython_fast_sum',
#  'cxxparser',
#  'groo',
#  'login_main',
#  'urlib2',
#  'helpsupport',
#  'existingmodule',
#  'test_pack',
#  'etsywrapper',
#  '{pi',
#  'ampa',
#  'cifar10models',
#  'fees',
#  'shaders',
#  'bp_example',
#  'mdptoolbox',
#  'lcd_init',
#  'individual',
#  'reporteinmobiliario',
#  'myexception',
#  'user_module2',
#  'glwidget',
#  '/users/user/',
#  'mainscript',
#  'rolereaction',
#  'cu_widget',
#  '1sdjkhl',
#  'tag_pivot',
#  'vvisiteur',
#  '_grabscreen',
#  'myitems',
#  'mentoring_application',
#  'inistate',
#  'passwordchecker',
#  'timelabel',
#  'foo_bar',
#  'b_table',
#  'glf',
#  'teletubbies',
#  'prac2_link',
#  'random_py_file',
#  'gower_function',
#  'wenti3',
#  "'traceback'",
#  'requests&quot',
#  'backupdata',
#  'websitedb',
#  'getpi',
#  'milestone2',
#  'canbus',
#  'step_sequencer',
#  'evoalg_gen',
#  'libpcap_ext',
#  'ui_config_dialog',
#  'gui_screens',
#  'ssat_utils',
#  'cloudrasterizer',
#  'my_gis_library_of_choice',
#  'depthwiseconv3d',
#  'ftplip',
#  '{orgapiservice}',
#  'demos_tkinter',
#  'gumtree',
#  'oauth2api',
#  'test_module3',
#  'd_scraper2',
#  'xinhua',
#  '`tabitem',
#  'your_code',
#  'app_author',
#  'run_flask',
#  'rna_transcription',
#  'actif_class',
#  ...}

# %%
with open("data/results/python/python_all_libs_dates.json") as handle:
    data = json.load(handle)

# %%
denominator = sum([len(item) for item in data.values()]);denominator
# Out:
# 2839589

# %%
invalid_ones = {k:len(v) for k,v in data.items() if k.lower() not in package_names}

# %%
collections.Counter(invalid_ones).most_common(10)
# Out:
# [('mpl_toolkits', 5952),
#  ('RPi', 2114),
#  ('speech_recognition', 1271),
#  ('ruamel', 942),
#  ('gtk', 918),
#  ('module', 846),
#  ('paho', 786),
#  ('OpenGL', 767),
#  ('tkFileDialog', 754),
#  ('tkMessageBox', 704)]

# %%
numerator = sum([len(v) for k, v in data.items() if k.lower() in package_names]);numerator
# Out:
# 2727765

# %%
numerator/denominator
# Out:
# 0.9606196530554245
