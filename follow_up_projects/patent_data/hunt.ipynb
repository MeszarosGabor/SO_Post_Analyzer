# %%
import matplotlib.pyplot as plt
import numpy as np

import polyas_urn_model as pum

# %%
ROUNDS = 100_000
nei_1, nei_2 = 1, 10
noi_1, noi_2 = 100, 30
sim_1 = pum.run_simulation(epochs=1, rounds=ROUNDS, base_pool_size=100, new_element_increment=nei_1, new_opportunity_increment=noi_1, poisson_mean=2)
#sim_2 = pum.run_simulation(epochs=1, rounds=ROUNDS, base_pool_size=100, new_element_increment=nei_2, new_opportunity_increment=noi_2, poisson_mean=2)

xs = list(range(ROUNDS))
plt.plot(xs, sim_1['element_counts'], "k--",label=f"Individual Novelties (nei: {nei_1}, noi: {noi_1})")
#plt.plot(xs, sim_2['element_counts'], "r--",label=f"Individual Novelties (nei: {nei_2}, noi: {noi_2})")

#plt.plot(xs, sim['pairs_counts'],"b--", label="Pair Novelties")

# for alpha in [0.53]:
#     for index, c in enumerate([110]):
#         plt.plot(
#             xs,
#             [c * x ** alpha for x in xs],
#             "-", markerfacecolor="none",
#             label=f"alpha: {alpha} c: {c}",
#         )



plt.legend()
plt.title("Novelties in the Urn model")
# Out:
# 100%|████████████████████████████████████████████████████████████████████| 100000/100000 [00:00<00:00, 129467.41it/s]
# Text(0.5, 1.0, 'Novelties in the Urn model')
